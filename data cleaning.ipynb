# %%
#importation des librairies 

import pandas as pd
import numpy as np

# %%
#exportation des données du fichier source
data = pd.read_csv('fichier a nettoyer.csv')

# %%
data
# Out:
#        Unnamed: 0                  City Colors Reported Shape Reported State  \
# 0               0                Ithaca             NaN       TRIANGLE    NY
# 1               1           Willingboro             NaN          OTHER    NJ
# 2               2               Holyoke             NaN           OVAL    CO
# 3               3               Abilene             NaN           DISK    KS
# 4               4  New York Worlds Fair             NaN          LIGHT    NY
# ...           ...                   ...             ...            ...   ...
# 18236       18236            Grant Park             NaN       TRIANGLE    IL
# 18237       18237           Spirit Lake             NaN           DISK    IA
# 18238       18238           Eagle River             NaN            NaN    WI
# 18239       18239           Eagle River             RED          LIGHT    WI
# 18240       18240                  Ybor             NaN           OVAL    FL
#
#                    Time Unnamed: 6
# ...

# %%
#les differents types de données
data.dtypes
# Out:
# Unnamed: 0          int64
# City               object
# Colors Reported    object
# Shape Reported     object
# State              object
# Time               object
# Unnamed: 6         object
# dtype: object

# %%
#affichage de l'statistique
data.describe()
# Out:
#          Unnamed: 0
# count  18241.000000
# mean    9120.000000
# std     5265.867466
# min        0.000000
# 25%     4560.000000
# 50%     9120.000000
# 75%    13680.000000
# max    18240.000000

# %%
#verifications des valeurs manquantes
data.isna().sum()
# Out:
# Unnamed: 0             0
# City                  25
# Colors Reported    15357
# Shape Reported      2646
# State                  0
# Time                   0
# Unnamed: 6         18239
# dtype: int64

# %%
data
# Out:
#        Unnamed: 0                  City Colors Reported Shape Reported State  \
# 0               0                Ithaca             NaN       TRIANGLE    NY
# 1               1           Willingboro             NaN          OTHER    NJ
# 2               2               Holyoke             NaN           OVAL    CO
# 3               3               Abilene             NaN           DISK    KS
# 4               4  New York Worlds Fair             NaN          LIGHT    NY
# ...           ...                   ...             ...            ...   ...
# 18236       18236            Grant Park             NaN       TRIANGLE    IL
# 18237       18237           Spirit Lake             NaN           DISK    IA
# 18238       18238           Eagle River             NaN            NaN    WI
# 18239       18239           Eagle River             RED          LIGHT    WI
# 18240       18240                  Ybor             NaN           OVAL    FL
#
#                    Time Unnamed: 6
# ...
